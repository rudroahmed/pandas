# %% [markdown]
# <a href="https://colab.research.google.com/github/rudroahmed/pandas/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data=[2,6,8,10,14,4,3,5,7,12]

# %%
type(data)
# Out:
# list

# %%
import pandas as pd
df1 = pd.DataFrame(data,columns=['Number2'])
df1
# Out:
#    Number2
# 0        2
# 1        6
# 2        8
# 3       10
# 4       14
# 5        4
# 6        3
# 7        5
# 8        7
# 9       12
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df1['Number2'].plot(kind='hist', bins=20, title='Number2')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df1['Number2'].plot(kind='line', figsize=(8, 4), title='Number2')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
series2=df1['Number2']
series2
# Out:
# 0     2
# 1     6
# 2     8
# 3    10
# 4    14
# 5     4
# 6     3
# 7     5
# 8     7
# 9    12
# Name: Number2, dtype: int64

# %%
type(series2)
# Out:
# pandas.core.series.Series

# %%
data2=[[1,2],[2,3],[3,4],[4,5]]

# %%
data2
# Out:
# [[1, 2], [2.3], [3, 4], [4, 5]]

# %%
df=pd.DataFrame(data2,columns=['Num1','Num2'])
df
# Out:
#    Num1  Num2
# 0     1     2
# 1     2     3
# 2     3     4
# 3     4     5

# %%
series=df[['Num1','Num2']]
series
# Out:
#    Num1  Num2
# 0     1     2
# 1     2     3
# 2     3     4
# 3     4     5
